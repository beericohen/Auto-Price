# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'c:\Users\USER\Documents\Auto-Price/data/autoboom_clean.csv')

# %%
dummies = pd.get_dummies(df, dtype=int)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df.columns
# Out:
# Index(['manufacturer', 'model', 'year', 'price', 'hand', 'fuel',
#        'engine_liters', 'horsepower', 'transmission', 'mileage', 'is_electro'],
#       dtype='str')

# %%
cols_to_scale = ['year', 'price', 'hand', 'engine_liters', 'horsepower', 'mileage']
dummies[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
dummies.to_csv(r'c:\Users\USER\Documents\Auto-Price/data/preprocessing.csv')
