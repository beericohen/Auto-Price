# %%
import pandas as pd
import numpy as np
import joblib

# %%
df = pd.read_csv(r'c:\Users\USER\Documents\Auto-Price/data/autoboom_clean.csv', index_col=False)

# %%
df = df.fillna(0)

# %%
dummies = pd.get_dummies(df, dtype=int)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
Yscaler = MinMaxScaler()

# %%
df.columns
# Out:
# Index(['manufacturer', 'model', 'year', 'price', 'hand', 'fuel',
#        'engine_liters', 'horsepower', 'transmission', 'mileage'],
#       dtype='str')

# %%
cols_to_scale = ['year', 'hand', 'engine_liters', 'horsepower', 'mileage']
dummies[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])
dummies['price'] = Yscaler.fit_transform(df[['price']])

# %%
joblib.dump(Yscaler, r'c:\Users\USER\Documents\Auto-Price/data/minmax_scaler.pkl')
joblib.dump(scaler, r'c:\Users\USER\Documents\Auto-Price/data/scaler.pkl')
# Out:
# ['c:\\Users\\USER\\Documents\\Auto-Price/data/scaler.pkl']

# %%
dummies.to_csv(r'c:\Users\USER\Documents\Auto-Price/data/preprocessing.csv')
